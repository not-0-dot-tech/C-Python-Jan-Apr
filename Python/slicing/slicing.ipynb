# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[1 : 4]
# Out:
# ['Fardeen', 'Megha', 'Rahul']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-4 : 5]
# Out:
# ['Megha', 'Rahul', 'Sumita']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[1 : -1 : 2]
# Out:
# ['Fardeen', 'Rahul']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[1 : : 2]
# Out:
# ['Fardeen', 'Rahul', 'Rohini']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[1 : 3 : -1]
# Out:
# []

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-2 : 0 : -1]
# Out:
# ['Sumita', 'Rahul', 'Megha', 'Fardeen']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-2 : 0 : -2]
# Out:
# ['Sumita', 'Megha']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-4 : ]
# Out:
# ['Megha', 'Rahul', 'Sumita', 'Rohini']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-4 : : 2]
# Out:
# ['Megha', 'Sumita']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-4 : : -1]
# Out:
# ['Megha', 'Fardeen', 'Avik']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[-4 : : -2]
# Out:
# ['Megha', 'Avik']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[ : 2]
# Out:
# ['Avik', 'Fardeen']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[ : 2 : -1]
# Out:
# ['Rohini', 'Sumita', 'Rahul']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[ : ]
# Out:
# ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

# %%
my_list = ['Avik', 'Fardeen', 'Megha', 'Rahul', 'Sumita', 'Rohini']

my_list[ : : -1]
# Out:
# ['Rohini', 'Sumita', 'Rahul', 'Megha', 'Fardeen', 'Avik']

# %%
# Reverse a string

s = 'UEMK'

print(s[ : : -1])
# Out:
# KMEU
