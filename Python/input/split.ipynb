# %%
s = 'My name is Avik Agarwala'
l = s.split() # by default it splits by whitespace
l
# Out:
# ['My', 'name', 'is', 'Avik', 'Agarwala']

# %%
s = 'Avik,Rajdeep,Pratyay'
s.split(',')
# Out:
# ['Avik', 'Rajdeep', 'Pratyay']

# %%
s = '12 45 23 98 75'
l = s.split()

for i in range(len(l)): # 0
    l[i] = int(l[i])

l
# Out:
# [12, 45, 23, 98, 75]

# %%
# s = input()
# l = s.split()
l = input().split() # ['1', '2', '3', '4', '5']

# calling int() on each element
for i in range(len(l)):
    l[i] = int(l[i])

l
# Out:
# [1, 2, 3, 4, 5]
