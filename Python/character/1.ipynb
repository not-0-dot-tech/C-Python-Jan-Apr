# %%
ch = 'a'

print(type(ch))
# Out:
# <class 'str'>

# %%
# printing the ASCII value of the character

print(ord(ch))
# Out:
# 97

# %%
# printing the character of the ASCII value

print(chr(97))
# Out:
# a
