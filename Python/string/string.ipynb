# %%
print("Hello world")

# I know that
# this is a comment
# which is commented out with
# tripple quotes
# Out:
# Hello world
# 'I know that\nthis is a comment\nwhich is commented out with\ntripple quotes'

# %%
# multiline string
print('''Hello
World
Avik''')
# Out:
# Hello
# World
#       Avik

# %%
name = 'Avik Agarwala'

name[3] # k
# Out:
# 'k'

# %%
name 'Avik'

name[67] # IndexError: string index out of range
# Out:
#   Cell In[10], line 1
#     name 'Avik'
#          ^
# SyntaxError: invalid syntax

# %%
str = 'Avik'

for i in range(len(str)):
    print(str[i], end = ' ')
# Out:
# A v i k

# %%
str = 'Avik'

for i in str:
    print(i, end = ' ')
# Out:
# A v i k

# %%
name = 'Ishita'

print('F' in name)
print('I' in name)
print('F' not in name)
print('I' not in name)
# Out:
# False
# True
# True
# False

# %%
name = 'Avik'

name[0] = 'B' # TypeError: 'str' object does not support item assignment

name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 name = 'Avik'
# ----> 3 name[0] = 'B'
#       5 name
#
# TypeError: 'str' object does not support item assignment

# %%
name = 'Avik'
name = list(name)
name[0] = 'B'
name = ''.join(name)
name
# Out:
# 'Bvik'

# %%
'Kolkata' in 'I live in Kolkata'
# Out:
# True

# %%
str = 'I am Avik Agarwala'
print(str.lower())
print(str)
# Out:
# i am avik agarwala
# I am Avik Agarwala

# %%
str = 'I am Avik Agarwala'
str.split()
# Out:
# ['I', 'am', 'Avik', 'Agarwala']

# %%
str = 'Cat, Dog, Fish'
str.split(', ')
# Out:
# ['Cat', 'Dog', 'Fish']

# %%
# Removing leading and trailing whitespaces
str = '         Avik Agarwala            '
print(str.strip())  # Output: Avik Agarwala
# Out:
# Avik Agarwala

# %%
str = 'UEM Kolkata'

str.replace('UEM', 'University of Engineering and Management,')
# Out:
# 'University of Engineering and Management, Kolkata'

# %%
str = 'Avik Agarwala'

str.find('A') # the first occurence of 'A' is at index 0
# Out:
# 0

# %%
'Avik' + ' ' + 'Agarwala'
# Out:
# 'Avik Agarwala'
